# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %load_ext autoreload
# %autoreload 2

# load general packages
import numpy as np
import time
import copy

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# load modules related to this exercise

# load general packages
import numpy as np
# load modules related to this exercise
from model_zucher import zurcher
from Solve_NFXP import solve_NFXP
import estimate_NFXP as estimate

# %% [markdown]
# # Exercise 2

# %% [markdown]
# #### 1. Ensure that you understand the code zucher.sim_data

# %% [markdown]
# #### 2. Illustrate the likelihood function for different values of RC and c

# %%
# Simulate the data

# Set up
model = zurcher()
solver = solve_NFXP()

# update starting value: 
N = 1000
T = 500
ev0 = np.zeros((model.n))
ev,pk = solver.poly(model.bellman, ev0, beta = model.beta, output=2)

# data
data = zurcher.sim_data(model,N,T,pk) 
samplesize = data.shape[0]

# %%
# Find tha likelihood value for different combinations 
ev = np.zeros((model.n))
par_RC = copy.copy(model.RC)
par_c = copy.copy(model.c)

NRC = 30
Nc = 20

log_lik = np.nan + np.zeros((NRC,Nc))
RC= np.linspace(8,15,NRC)
c = np.linspace(1,4,Nc)

for i in range(NRC):
    for j in range(Nc):
       
        # STEP 1: Find p 
        tabulate = data.dx1.value_counts()
        p = [tabulate[i]/sum(tabulate) for i in range(tabulate.size-1)]

        # STEP 2: Estimate structual parameters
        model.p = p # Use first step estimates as starting values for t
    
        # Estimate RC and C
        pnames = ['RC','c']
        theta = np.array([RC[i], c[j]])
        log_lik[i,j]=estimate.ll(theta,model, solver,data, pnames, no_guess=True)

log_lik *= samplesize*(-1)

#Re-inset the true parameters 
model.RC = copy.copy(par_RC)
model.c = copy.copy(par_c)

# %%
# plot figure in three dimensions
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
plt.style.use('seaborn-whitegrid')


fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1,1,1,projection='3d', computed_zorder=False)

# Make data.
X, Y = np.meshgrid(RC, c,indexing='ij')
x, y = np.unravel_index(np.argmax(log_lik), log_lik.shape)

# Plot the surface.
surf = ax.plot_surface(X, Y, log_lik, cmap=cm.jet)

#Plot max value
max = ax.scatter(RC[x], c[y], log_lik[x,y], color=['black'], marker='o', s=10)

# Customize the axis.
ax.set_xlabel(f'RC')
ax.set_ylabel(f'c')
ax.set_title(f'Log-likelihood (RC,c)')
ax.invert_xaxis()

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# #### 3. Estimate the model, do you get the correct estimates?

# %%
theta0 = [0,0]
# Estimate
nfxp_model, nfxp_results, pnames, theta_hat, Avar, converged=estimate.estimate(model, solver,data,theta0=theta0)

print(f'Log-Likelihood:     {-nfxp_results.fun*samplesize:.4f}')
print(f'RC:                 {theta_hat[0]:.4f}')
print(f'c:                  {theta_hat[1]:.4f}')
# Out:
# Log-Likelihood:     -531115.6378
# RC:                 11.7064
# c:                  2.4449

# %% [markdown]
# a) Try changing the starting values, does the model converges?

# %%
#starting values
rc_vec = np.array((0,12))
c_vec = np.array((0, 2, 40))

for i,rc in enumerate(rc_vec):
    for j, c in enumerate(c_vec):
        print(f'starting values: ({rc},{c})')
        t0 = time.time()
        
        # Update start values
        theta0 = [rc, c]
        
        # Estimate
        nfxp_model, nfxp_results, pnames, theta_hat, Avar, converged=estimate.estimate(model, solver,data,theta0=theta0)
        t1 = time.time()
        print(f'RC = {theta_hat[0]:.4f}, c = {theta_hat[1]:.4f}')
        print(f'The model converged: {converged}')
        print(f'Total time = {t1-t0:.4f} \n')
# Out:
# starting values: (0,0)
# RC = 11.7064, c = 2.4449
# The model converged: True
# Total time = 2.5514
#
# starting values: (0,2)
# RC = 11.7065, c = 2.4449
# The model converged: True
# Total time = 2.4352
#
# starting values: (0,40)
# RC = 11.7065, c = 2.4449
# The model converged: True
# Total time = 3.2846
#
# starting values: (12,0)
# RC = 11.7064, c = 2.4449
# The model converged: True
# Total time = 3.0520
#
# starting values: (12,2)
# RC = 11.7065, c = 2.4449
# The model converged: True
# Total time = 1.9310
#
# starting values: (12,40)
# RC = 11.7064, c = 2.4449
# The model converged: True
# Total time = 4.2330

# %% [markdown]
# #### 4. What happen if you change the maximum number of Newton-Kantorovich iterations and switches between NK and SA to 1?
# Do we get convergence? Do the estimates seem right?

# %%
do_settings_solver = {
    'pi_max': 1,
    'max_fxpiter': 1,  
    'printfxp': 1
}

solver = solve_NFXP(**do_settings_solver)
model = zurcher()
nfxp_model, nfxp_results, pnames, theta_hat, Avar, converged=estimate.estimate(model, solver,data,theta0=[0,0])
# Out:
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0060 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 3.638e-12
# Elapsed time 0.0020 seconds
# Convergence achieved!
# Elapsed time: 0.0091 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 9.095e-13
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 9.095e-13
# Elapsed time 0.0022 seconds
# Convergence achieved!
# Elapsed time: 0.0038 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 9.095e-13
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 9.095e-13
# Elapsed time 0.0034 seconds
# Convergence achieved!
# Elapsed time: 0.0047 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0025 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0019 seconds
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.226e-08
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 9.095e-13
# Elapsed time 0.0032 seconds
# Convergence achieved!
# Elapsed time: 0.0044 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 4.547e-13
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 4.547e-13
# Elapsed time 0.0049 seconds
# Convergence achieved!
# Elapsed time: 0.0065 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0186
# Elapsed time 0.0034 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0024 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0059
# Elapsed time 0.0019 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0016 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0135
# Elapsed time 0.0039 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0026 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0113
# Elapsed time 0.0021 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0010 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0009
# Elapsed time 0.0031 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0020 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0013 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0006
# Elapsed time 0.0017 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0003
# Elapsed time 0.0039 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0009 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0010 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0018 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0024 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0009 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0013 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0016 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0010 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 4.319e-10
# Elapsed time 0.0010 seconds
# Convergence achieved!
# Elapsed time: 0.0021 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.706e-11
# Elapsed time 0.0015 seconds
# Convergence achieved!
# Elapsed time: 0.0031 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0023 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.819e-12
# Elapsed time 0.0031 seconds
# Convergence achieved!
# Elapsed time: 0.0056 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 3.411e-13
# Elapsed time 0.0033 seconds
# Convergence achieved!
# Elapsed time: 0.0045 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 3.016e-08
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0037 seconds
# Convergence achieved!
# Elapsed time: 0.0049 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 7.541e-09
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0012 seconds
# Convergence achieved!
# Elapsed time: 0.0023 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.885e-09
# Elapsed time 0.0089 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0411 seconds
# Convergence achieved!
# Elapsed time: 0.0502 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 4.716e-10
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0844 seconds
# Convergence achieved!
# Elapsed time: 0.0857 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.179e-10
# Elapsed time 0.0471 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0373 seconds
# Convergence achieved!
# Elapsed time: 0.0849 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.967e-11
# Elapsed time 0.0017 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0171 seconds
# Convergence achieved!
# Elapsed time: 0.0190 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 7.503e-12
# Elapsed time 0.0024 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0019 seconds
# Convergence achieved!
# Elapsed time: 0.0045 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.046e-12
# Elapsed time 0.0017 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0014 seconds
# Convergence achieved!
# Elapsed time: 0.0032 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 5.684e-13
# Elapsed time 0.0013 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 3.411e-13
# Elapsed time 0.0017 seconds
# Convergence achieved!
# Elapsed time: 0.0031 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0017 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0015 seconds
# Convergence achieved!
# Elapsed time: 0.0033 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0050 seconds
# Convergence achieved!
# Elapsed time: 0.0063 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0018 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0015 seconds
# Convergence achieved!
# Elapsed time: 0.0034 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.137e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0023 seconds
# Convergence achieved!
# Elapsed time: 0.0034 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0026 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.137e-13
# Elapsed time 0.0045 seconds
# Convergence achieved!
# Elapsed time: 0.0072 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0010 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0018 seconds
# Convergence achieved!
# Elapsed time: 0.0028 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.137e-13
# Elapsed time 0.0013 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.137e-13
# Elapsed time 0.0572 seconds
# Convergence achieved!
# Elapsed time: 0.0586 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0020 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0019 seconds
# Convergence achieved!
# Elapsed time: 0.0040 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.137e-13
# Elapsed time 0.0020 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.137e-13
# Elapsed time 0.0034 seconds
# Convergence achieved!
# Elapsed time: 0.0055 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.137e-13
# Elapsed time 0.0026 seconds
# Convergence achieved!
# Elapsed time: 0.0043 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0016 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0157
# Elapsed time 0.0022 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0009 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0044
# Elapsed time 0.0010 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0007
# Elapsed time 0.0017 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0021 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0015 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0017 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0024 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0025 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# Maximum number of iterations reached, tolerance: 0.0000
# Elapsed time 0.0032 seconds
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.16e-10
# Elapsed time 0.0041 seconds
# Convergence achieved!
# Elapsed time: 0.0054 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.364e-11
# Elapsed time 0.0021 seconds
# Convergence achieved!
# Elapsed time: 0.0033 (seconds)
# Begin contraction iterations (for the 1 time)
# SA stopped prematurely due to relative tolerance. Start NK iterations
# Elapsed time 0.0018 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.023e-12
# Elapsed time 0.0017 seconds
# Convergence achieved!
# Elapsed time: 0.0036 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 7.566e-08
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0043 seconds
# Convergence achieved!
# Elapsed time: 0.0059 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.891e-08
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0020 seconds
# Convergence achieved!
# Elapsed time: 0.0032 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 4.729e-09
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0021 seconds
# Convergence achieved!
# Elapsed time: 0.0033 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.182e-09
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0020 seconds
# Convergence achieved!
# Elapsed time: 0.0033 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.955e-10
# Elapsed time 0.0010 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0020 seconds
# Convergence achieved!
# Elapsed time: 0.0030 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 7.401e-11
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0031 seconds
# Convergence achieved!
# Elapsed time: 0.0043 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.864e-11
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0033 seconds
# Convergence achieved!
# Elapsed time: 0.0046 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 4.775e-12
# Elapsed time 0.0013 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0016 seconds
# Convergence achieved!
# Elapsed time: 0.0030 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 1.251e-12
# Elapsed time 0.0014 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0022 seconds
# Convergence achieved!
# Elapsed time: 0.0037 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 4.547e-13
# Elapsed time 0.0023 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 3.411e-13
# Elapsed time 0.0024 seconds
# Convergence achieved!
# Elapsed time: 0.0049 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0017 seconds
# Convergence achieved!
# Elapsed time: 0.0029 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0019 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0033 seconds
# Convergence achieved!
# Elapsed time: 0.0053 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0054 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0046 seconds
# Convergence achieved!
# Elapsed time: 0.0101 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0024 seconds
# Convergence achieved!
# Elapsed time: 0.0036 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0016 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0018 seconds
# Convergence achieved!
# Elapsed time: 0.0035 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0017 seconds
# Convergence achieved!
# Elapsed time: 0.0029 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0012 seconds
# Convergence achieved!
# Elapsed time: 0.0025 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0026 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0046 seconds
# Convergence achieved!
# Elapsed time: 0.0073 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0012 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 1.137e-13
# Elapsed time 0.0019 seconds
# Convergence achieved!
# Elapsed time: 0.0032 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0013 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0060 seconds
# Convergence achieved!
# Elapsed time: 0.0074 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0015 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0014 seconds
# Convergence achieved!
# Elapsed time: 0.0030 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0028 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0022 seconds
# Convergence achieved!
# Elapsed time: 0.0051 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0024 seconds
# Convergence achieved!
# Elapsed time: 0.0037 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0018 seconds
# Convergence achieved!
# Elapsed time: 0.0030 (seconds)
# Begin contraction iterations (for the 1 time)
# SA converged after 10 iterations, tolerance: 2.274e-13
# Elapsed time 0.0011 seconds
# Begin Newton-Kantorovich iterations (for the 1 time)
# N-K converged after 1 iterations, tolerance: 2.274e-13
# Elapsed time 0.0017 seconds
# Convergence achieved!
# Elapsed time: 0.0029 (seconds)

# %%
print(f'Log-Likelihood:     {-nfxp_results.fun*samplesize:.4f}')
print(f'RC:                 {theta_hat[0]:.4f}')
print(f'c:                  {theta_hat[1]:.4f}')
# Out:
# Log-Likelihood:     -546314.2431
# RC:                 3.4434
# c:                  -0.3079
